# %%
import pandas as pd
df=pd.read_csv('../string_manipulation/titanic_data.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# age of the Titanic passengers.
age=df['Age']
age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
# age and sex of the Titanic passengers.
age_sex = df[['Age', 'Sex']]
age_sex
# Out:
#       Age Sex
# 0    22.0   M
# 1    38.0   F
# 2    26.0   F
# 3    35.0   F
# 4    35.0   M
# ..    ...  ..
# 886  27.0   M
# 887  19.0   F
# 888   NaN   F
# 889  26.0   M
# 890  32.0   M
#
# [891 rows x 2 columns]

# %%
# data type of age and sex
type(df[['Age','Sex']])
# Out:
# pandas.core.frame.DataFrame

# %%
# passengers older than 35 years.
# df.loc[df['Age']>35]
df[df['Age']>35]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   F  38.0      1
# 6                              McCarthy, Mr. Timothy J   M  54.0      0
# 11                             Bonnell, Miss Elizabeth   F  58.0      0
# 13                         Andersson, Mr. Anders Johan   M  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)    F  55.0      0
# ..                                                 ...  ..   ...    ...
# ...

# %%
# Titanic passengers from cabin class 2 and 3.
# df[df['Pclass'].isin([2,3])]
class_23=df[(df['Pclass']==2) | (df['Pclass']==3)]
class_23
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss Laina
# 4              5         0       3                 Allen, Mr. William Henry
# 5              6         0       3                         Moran, Mr. James
# 7              8         0       3            Palsson, Master Gosta Leonard
# ..           ...       ...     ...                                      ...
# 884          885         0       3                   Sutehall, Mr. Henry Jr
# 885          886         0       3     Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                    Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss Catherine Helen "Carrie"
# 890          891         0       3                      Dooley, Mr. Patrick
#
# ...

# %%
# passenger data for which the age is known.
age_known = df[df['Age'].isna()]
age_known
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 5              6         0       3                         Moran, Mr. James
# 17            18         1       2             Williams, Mr. Charles Eugene
# 19            20         1       3                  Masselmani, Mrs. Fatima
# 26            27         0       3                  Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss Ellen "Nellie"
# ..           ...       ...     ...                                      ...
# 859          860         0       3                         Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss Dorothy Edith "Dolly"
# 868          869         0       3              van Melkebeke, Mr. Philemon
# 878          879         0       3                       Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss Catherine Helen "Carrie"
#
# ...

# %%
# names of the passengers older than 35 years.
names = df.loc[df['Age']>35, 'Name']
names.head()
# Out:
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6                               McCarthy, Mr. Timothy J
# 11                              Bonnell, Miss Elizabeth
# 13                          Andersson, Mr. Anders Johan
# 15                     Hewlett, Mrs. (Mary D Kingcome)
# Name: Name, dtype: object

# %%
# rows 10 till 25 and columns 3 to 5.
df.iloc[10:25, 2:5]
# Out:
#     Pclass                                               Name Sex
# 10       3                     Sandstrom, Miss Marguerite Rut   F
# 11       1                            Bonnell, Miss Elizabeth   F
# 12       3                     Saundercock, Mr. William Henry   M
# 13       3                        Andersson, Mr. Anders Johan   M
# 14       3                Vestrom, Miss Hulda Amanda Adolfina   F
# 15       2                   Hewlett, Mrs. (Mary D Kingcome)    F
# 16       3                                Rice, Master Eugene   M
# 17       2                       Williams, Mr. Charles Eugene   M
# 18       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...   F
# 19       3                            Masselmani, Mrs. Fatima   F
# 20       2                               Fynney, Mr. Joseph J   M
# 21       2                              Beesley, Mr. Lawrence   M
# 22       3                         McGowan, Miss Anna "Annie"   F
# ...
